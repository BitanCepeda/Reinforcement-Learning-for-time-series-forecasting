# %%
import numpy as np 
import pandas as pd 
import matplotlib
import matplotlib.pyplot as plt 
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
# Read the dataset 
tem = pd.read_csv('Datos/RSSI/20m/raw_data_run8--2.csv', 
                       index_col ='Date', 
                       parse_dates = True) 
  

cantidad=len(tem)
print(cantidad)
# Out:
# 8064

# %%
tem.plot(figsize=(20,4))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#hallamos la varianza
varianza = tem['RSSI'].var(ddof=0)
print("Varianza")
print(varianza)
# Out:
# Varianza
# 72.64361146295902

# %%
#hallamos la desviación estándar
estandar = tem['RSSI'].std(ddof=0)
print("Desviación estándar")
print(estandar)
# Out:
# Desviación estándar
# 8.52312216637536
