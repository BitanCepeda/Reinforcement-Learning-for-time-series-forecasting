# %%
import numpy as np 
import pandas as pd 
import matplotlib
import matplotlib.pyplot as plt 
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
# Read the dataset 
tem = pd.read_csv('Datasets limpios LQI/20m/raw_data_run1--27.csv', 
                       index_col ='Date', 
                       parse_dates = True) 
  

cantidad=len(tem)
print(cantidad)
# Out:
# 8064

# %%
# Print the first five rows of the dataset 
tem.head(10)
# Out:
#       LQI
# Date
# 1       1
# 2     101
# 3     105
# 4       1
# 5      87
# 6     103
# 7     105
# 8     101
# 9       1
# 10    100

# %%
tem.plot(figsize=(20,4))
# Out:
# <AxesSubplot:xlabel='Date'>
